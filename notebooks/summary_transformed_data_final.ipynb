# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
summary_capacity = pd.read_csv("summary_charge_capacity.csv", usecols=range(0,100)).drop(columns = 'barcode')
summary_capacity
# Out:
#             0         1         2         3         4         5         6  \
# 0    1.441996  1.068214  1.068963  1.073107  1.071258  1.073530  1.073236
# 1    1.043969  1.044813  1.046080  1.046788  1.047803  1.048233  1.048794
# 2    1.064999  1.067030  1.068190  1.068785  1.069359  1.070008  1.070455
# 3    1.160316  1.076760  1.079541  1.080560  1.081084  1.081451  1.081686
# 4    1.161226  1.069269  1.071042  1.071674  1.072304  1.072970  1.073491
# ..        ...       ...       ...       ...       ...       ...       ...
# 130  1.452700  1.076223  1.080073  1.081467  1.082190  1.082694  1.082749
# 131  1.445301  1.069201  1.072274  1.073339  1.073858  1.074621  1.074464
# 132  1.454137  1.078564  1.082698  1.084270  1.085315  1.086124  1.086118
# 133  1.047174  1.048364  1.050240  1.051151  1.052067  1.052452  1.052797
# 134  1.065699  1.067577  1.068817  1.069808  1.070383  1.070976  1.071374
#
#             7         8         9  ...        89        90        91  \
# ...

# %%
summary_capacity.min().min()
# Out:
# 0.97366512

# %%
summary_capacity = pd.read_csv("summary_charge_capacity.csv", usecols=range(0,100)).drop(columns = 'barcode')
summary_capacity0 = pd.DataFrame(summary_capacity.iloc[0,1:])
plt.plot(summary_capacity0)

# %%
summary_capacity.iloc[0,1:]
# Out:
# 1     1.068214
# 2     1.068963
# 3     1.073107
# 4     1.071258
# 5     1.073530
#         ...
# 94    1.076209
# 95    1.076727
# 96    1.076992
# 97    1.075993
# 98    1.076599
# Name: 0, Length: 98, dtype: float64

# %%
plt.figure(figsize=(25,25))

for i in range (25):
    plt.subplot(5,5,i+1)
    
    sns.lineplot(data = summary_capacity.iloc[i,1:])
    
plt.show()

# %%
for i in range (25):
    sns.lineplot(data = summary_capacity.iloc[i+1,1:])

plt.show()

# %%
summary_discharge = pd.read_csv("summary_discharge_capacity.csv", usecols=range(0,100)).drop(columns = 'barcode')

plt.figure(figsize=(25,25))
for i in range (25):
    plt.subplot(5,5,i+1)
    sns.lineplot(data = summary_discharge.iloc[i,1:])

plt.show()

# %%
for i in range (25):
    sns.lineplot(data = summary_discharge.iloc[i+1,1:])

plt.show()

# %%
summary_temp = pd.read_csv("summary_temperature_average.csv", usecols=range(0,100)).drop(columns = 'barcode')

plt.figure(figsize=(25,25))
for i in range (25):
    plt.subplot(5,5,i+1)
    sns.lineplot(data = summary_temp.iloc[i,1:])

plt.show()

# %%
for i in range (25):
    sns.lineplot(data = summary_temp.iloc[i+1,1:])

plt.show()

# %%
summary_duration = pd.read_csv("summary_charge_duration.csv", usecols=range(0,50)).drop(columns = 'barcode')


plt.figure(figsize=(25,25))
for i in range (25):
    plt.subplot(5,5,i+1)
    sns.lineplot(data = summary_duration.iloc[i,1:])

plt.show()

# %%
for i in range (25):
    sns.lineplot(data = summary_duration.iloc[i+1,1:])

plt.show()

# %%
summary_duration = pd.DataFrame(summary_duration.iloc[0,1:])
plt.plot(summary_duration );

# %%
summary_charge_energy = pd.read_csv("summary_charge_energy.csv", usecols=range(0,50)).drop(columns = 'barcode')


plt.figure(figsize=(25,25))
for i in range (25):
    plt.subplot(5,5,i+1)
    sns.lineplot(data = summary_charge_energy.iloc[i,1:])

plt.show()

# %%
for i in range (25):
    sns.lineplot(data = summary_charge_energy.iloc[i+1,1:])

plt.show()

# %%
summary_discharge_energy = pd.read_csv("summary_discharge_energy.csv", usecols=range(0,50)).drop(columns = 'barcode')


plt.figure(figsize=(25,25))
for i in range (25):
    plt.subplot(5,5,i+1)
    sns.lineplot(data = summary_discharge_energy.iloc[i,1:])

plt.show()

# %%
for i in range (25):
    sns.lineplot(data = summary_discharge_energy.iloc[i+1,1:])

plt.show()

# %%
summary_energy_efficiency = pd.read_csv("summary_energy_efficiency.csv", usecols=range(0,50)).drop(columns = 'barcode')


plt.figure(figsize=(25,25))
for i in range (25):
    plt.subplot(5,5,i+1)
    sns.lineplot(data = summary_energy_efficiency.iloc[i,1:])

plt.show()

# %%
for i in range (25):
    sns.lineplot(data = summary_energy_efficiency.iloc[i+1,1:])

plt.show()

# %%
summary_duration = pd.read_csv("summary_dc_internal_resistance.csv", usecols=range(0,50)).drop(columns = 'barcode')


plt.figure(figsize=(25,25))
for i in range (25):
    plt.subplot(5,5,i+1)
    sns.lineplot(data = summary_duration.iloc[i,1:])

plt.show()

# %%
summary_duration = pd.read_csv("summary_dc_internal_resistance.csv", usecols=range(0,50)).drop(columns = 'barcode')


for i in range (25):
    sns.lineplot(data = summary_duration.iloc[i+1,1:])

plt.show()

# %%
summary_duration = pd.read_csv("summary_dc_internal_resistance.csv", usecols=range(0,50)).drop(columns = 'barcode')


for i in range (25):
    sns.lineplot(data = summary_duration.iloc[i+1,1:])

plt.show()

# %%
"""
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation

# Create new Figure with black background
fig = plt.figure(figsize=(8, 8), facecolor='black')

# Add a subplot with no frame
ax = plt.subplot(frameon=False)

# Generate random data
data = summary_capacity2
X = np.linspace(-1, 1, data)
G = 1.5 * np.exp(-4 * X ** 2)

# Generate line plots
lines = []
for i in range(len(data)):
    # Small reduction of the X extents to get a cheap perspective effect
    xscale = 1 - i / 200.
    # Same for linewidth (thicker strokes on bottom)
    lw = 1.5 - i / 100.0
    line, = ax.plot(xscale * X, i + G * data[i], color="w", lw=lw)
    lines.append(line)

# Set y limit (or first line is cropped because of thickness)
ax.set_ylim(-1, 70)

# No ticks
ax.set_xticks([])
ax.set_yticks([])

# 2 part titles to get different font weights
ax.text(0.5, 1.0, "MATPLOTLIB ", transform=ax.transAxes,
        ha="right", va="bottom", color="w",
        family="sans-serif", fontweight="light", fontsize=16)
ax.text(0.5, 1.0, "UNCHAINED", transform=ax.transAxes,
        ha="left", va="bottom", color="w",
        family="sans-serif", fontweight="bold", fontsize=16)


def update(*args):
    # Shift all data to the right
    data[:, 1:] = data[:, :-1]

    # Fill-in new values
    data[:, 0] = np.random.uniform(0, 1, len(data))

    # Update data
    for i in range(len(data)):
        lines[i].set_ydata(i + G * data[i])

    # Return modified artists
    return lines

# Construct the animation, using the update function as the animation director.
anim = animation.FuncAnimation(fig, update, interval=10)
plt.show()"""
# Out:
# '\nimport numpy as np\nimport matplotlib.pyplot as plt\nimport matplotlib.animation as animation\n\n# Create new Figure with black background\nfig = plt.figure(figsize=(8, 8), facecolor=\'black\')\n\n# Add a subplot with no frame\nax = plt.subplot(frameon=False)\n\n# Generate random data\ndata = summary_capacity2\nX = np.linspace(-1, 1, data)\nG = 1.5 * np.exp(-4 * X ** 2)\n\n# Generate line plots\nlines = []\nfor i in range(len(data)):\n    # Small reduction of the X extents to get a cheap perspective effect\n    xscale = 1 - i / 200.\n    # Same for linewidth (thicker strokes on bottom)\n    lw = 1.5 - i / 100.0\n    line, = ax.plot(xscale * X, i + G * data[i], color="w", lw=lw)\n    lines.append(line)\n\n# Set y limit (or first line is cropped because of thickness)\nax.set_ylim(-1, 70)\n\n# No ticks\nax.set_xticks([])\nax.set_yticks([])\n\n# 2 part titles to get different font weights\nax.text(0.5, 1.0, "MATPLOTLIB ", transform=ax.transAxes,\n        ha="right", va="bottom", color
# ...
