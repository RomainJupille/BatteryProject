# %% [markdown]
# **This notebook presents the results of the model one**
#  - Model performances
#  - Best model and its hyper parameters
#  - Testing the model performances

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os
import joblib

# %%
base_url = !pwd
base_url = base_url[0]
result_path = os.path.normpath(os.path.join(base_url, '..', 'BatteryProject', 'ModelOne', 'Models', 'Models_records.csv'))
result_path
# Out:
# '/home/romainj/code/RomainJupille/wagon/Projet_batteries/BatteryProject/BatteryProject/ModelOne/Models/Models_records.csv'

# %% [markdown]
# ## Results summary

# %% [markdown]
# ### Results table

# %%
results_df = pd.read_csv(result_path).drop(columns = ['Unnamed: 0'])
results_df
# Out:
#     Try_ID                   Model          Scaler Features_disc_capa  \
# 0        1      LogisticRegression    RobustScaler                  X
# 1        2      LogisticRegression  StandardScaler                  X
# 2        3      LogisticRegression    MinMaxScaler                  X
# 3        4  RandomForestClassifier    RobustScaler                  X
# 4        5  RandomForestClassifier  StandardScaler                  X
# 5        6  RandomForestClassifier    MinMaxScaler                  X
# 6        7      LogisticRegression    RobustScaler                  X
# 7        8      LogisticRegression  StandardScaler                  X
# 8        9      LogisticRegression    MinMaxScaler                  X
# 9       10  RandomForestClassifier    RobustScaler                  X
# 10      11  RandomForestClassifier  StandardScaler                  X
# 11      12  RandomForestClassifier    MinMaxScaler                  X
# ...

# %% [markdown]
# ### Performances of the model

# %%
plt.plot(results_df['Metrics_roc_auc'].sort_values().values)

# %% [markdown]
# ## Finding the best model

# %%
best_model = results_df.sort_values(by='Metrics_roc_auc', ascending = False).iloc[0,:]
best_model
# Out:
# Try_ID                                           13
# Model                            LogisticRegression
# Scaler                                 RobustScaler
# Features_disc_capa                                X
# Features_dis_ener                                 X
# Features_temp_avg                               NaN
# Features_char_capa                                X
# Features_eff_ener                                 X
# Features_char_ener                                X
# Features_dc_res                                   X
# Features_temp_min                               NaN
# Features_temp_max                               NaN
# Metrics_accuracy                           0.972222
# Metrics_precision                          0.956522
# Metrics_roc_auc                            0.964286
# HyperParams_max_iter                          500.0
# HyperParams_penalty                            none
# HyperParams_solver                            lbfgs
# ...

# %% [markdown]
# ## Testing the best model

# %%
model_id = str(best_model['Try_ID'])
for i in range(4-len(model_id)):
    model_id = ''.join(['0',model_id])
model_id
# Out:
# '0013'

# %%
base_url = !pwd
base_url = base_url[0]

raw_data_path = os.path.normpath(os.path.join(base_url, '..', 'BatteryProject', 'ModelOne', 'data', f"raw_data_{model_id}.csv"))
X_test_path = os.path.normpath(os.path.join(base_url, '..', 'BatteryProject', 'ModelOne', 'data', f"X_test_{model_id}.csv"))
y_test_path = os.path.normpath(os.path.join(base_url, '..', 'BatteryProject', 'ModelOne', 'data' , f"y_test_{model_id}.csv"))
model_path = os.path.normpath(os.path.join(base_url, '..', 'BatteryProject', 'ModelOne', 'Models' , f"model_{model_id}.joblib"))

# %%
df_raw_data_model_one = pd.read_csv(raw_data_path).iloc[1:,2:]
df_X_model_one = pd.read_csv(X_test_path)
df_y_model_one = pd.read_csv(y_test_path)
model = joblib.load(model_path)

# %%
df_raw_data_model_one.shape
# Out:
# (35, 3000)

# %%
df_X_model_one.shape
# Out:
# (35, 30)

# %%
df_y_model_one.shape
# Out:
# (35, 1)

# %% [markdown]
# ### Test a result randomly

# %% [markdown]
# **RUN THE CELL BELLOW TO TEST A RANDOM SAMPLE**

# %%
n = np.random.randint(0,df_raw_data_model_one.shape[0]-1)

X_sample = df_X_model_one.iloc[n,:].values
y_true = df_y_model_one.iloc[n].values[0]

X_val = df_X_model_one.iloc[n,:].values.reshape(1, -1)
prediction = model.predict(X_val)[0]
print("Prediction:", prediction)
print('Real value:', int(y_true))

f, axs = plt.subplots(1, 1, figsize=(8, 4))
sns.scatterplot(y = df_raw_data_model_one.iloc[n,:].fillna(0), x =np.arange(0,3000,1), ax = axs, color = 'blue', alpha = 0.5)
sns.lineplot(y = [0.8, 1.2], x = [550,550],color = 'red', ax = axs)
axs.set_ylim(0.8,1.2)
axs.set_yticks([0.8,0.9,1.0,1.1,1.2])
axs.set_xlim(0,2500)
axs.set_xticks(range(0,2501,250))
axs.set_ylabel('Capacity (in Ah)')
axs.set_xlabel('Number of cycle')
axs.tick_params(axis='both', which='major', labelsize=10)

if int(y_true) == prediction:
    print('The model got it right !!')
else :
    print('The model is wrong')
# Out:
# /home/romainj/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but RobustScaler was fitted with feature names
#   warnings.warn(
# Prediction: 1
# Real value: 1
# The model got it right !!

# %% [markdown]
# ### Average performance of the model

# %%
n_trials = 400


successes = 0
for i in range(n_trials):
    n = np.random.randint(0,df_raw_data_model_one.shape[0]-1)
    y_true = df_y_model_one.iloc[n].values[0]
    X_val = df_X_model_one.iloc[n,:].values.reshape(1, -1)
    
    prediction = model.predict(X_val)[0]
    if int(y_true) == prediction:
        successes += 1
# Out:
# /home/romainj/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but RobustScaler was fitted with feature names
#   warnings.warn(
# /home/romainj/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but RobustScaler was fitted with feature names
#   warnings.warn(
# /home/romainj/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but RobustScaler was fitted with feature names
#   warnings.warn(
# /home/romainj/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but RobustScaler was fitted with feature names
#   warnings.warn(
# ...

# %%
print(f"Average number of success {successes/n_trials}")
# Out:
# Average number of success 0.97
