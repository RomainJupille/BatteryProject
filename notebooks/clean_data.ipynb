# %%
import pandas as pd

from BatteryProject.params import *

# %%
#"summary_charge_capacity", "summary_charge_duration", "summary_charge_energy", "summary_charge_troughput", "summary_current", "summary_cycle_index", "test_details"
FEATURE_NAME = "summary_charge_capacity"
NROWS = None
RANGE_COL = None
df = pd.read_csv(f"../../Battery_data/{FEATURE_NAME}.csv",nrows = NROWS, usecols=RANGE_COL)

df.head(30)
# Out:
#            barcode         0         1         2         3         4  \
# 0   el150800460610  1.441996  1.068214  1.068963  1.073107  1.071258
# 1   el150800737368  1.043969  1.044813  1.046080  1.046788  1.047803
# 2   el150800737386  1.064999  1.067030  1.068190  1.068785  1.069359
# 3   EL150800463198  1.160316  1.076760  1.079541  1.080560  1.081084
# 4   EL150800460514  1.123774  1.019853  1.023291  1.022842  1.023315
# 5   el150800460599  1.407928  1.038380  1.041106  1.043239  1.044091
# 6   el150800463245  1.454874  1.075745  1.079504  1.081147  1.082164
# 7   EL150800460623  0.936862  1.026324  1.029869  1.031263  1.032870
# 8   EL150800464977  1.081503  0.973790  0.972563  0.971093  0.971524
# 9   el150800460501  1.448440  1.071397  1.074246  1.076030  1.076883
# 10  el150800460474  1.442470  1.066517  1.070743  1.072140  1.072904
# 11  el150800460526  1.448094  1.071990  1.075184  1.076492  1.078876
# 12  EL150800464883  1.164910  1.073538  1.076119  1.076585  1.077451
# ...

# %%
summary_duration = pd.read_csv("../../Battery_data/summary_charge_duration.csv")
summary_energy = pd.read_csv("../../Battery_data/summary_charge_energy.csv")
summary_throughput = pd.read_csv("../../Battery_data/summary_charge_throughput.csv")
summary_current = pd.read_csv("../../Battery_data/summary_charge_current.csv")
summary_cycle_index = pd.read_csv("../../Battery_data/summary_charge_capacity.csv")

# %%
# !gcloud auth activate-service-account service-battery-project@wagon-895-batteryproject.iam.gserviceaccount.com --key-file=/home/tom/code/TomG13100/gcp/wagon-895-batteryproject-4f75b2319a79.json --project=wagon-895-batteryproject
# Out:
# Activated service account credentials for: [service-battery-project@wagon-895-batteryproject.iam.gserviceaccount.com]
