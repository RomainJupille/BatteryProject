# %%
import pandas as pd

summary_capacity = pd.read_csv("../../Battery_data/summary_charge_capacity.csv", usecols=range(0,10))

summary_capacity.head(145)
# Out:
#             barcode         0         1         2         3         4  \
# 0    el150800460610  1.441996  1.068214  1.068963  1.073107  1.071258
# 1    el150800737368  1.043969  1.044813  1.046080  1.046788  1.047803
# 2    el150800737386  1.064999  1.067030  1.068190  1.068785  1.069359
# 3    EL150800463198  1.160316  1.076760  1.079541  1.080560  1.081084
# 4    EL150800460514  1.123774  1.019853  1.023291  1.022842  1.023315
# ..              ...       ...       ...       ...       ...       ...
# 135  el150800463208  1.452700  1.076223  1.080073  1.081467  1.082190
# 136  el150800460655  1.445301  1.069201  1.072274  1.073339  1.073858
# 137  el150800460652  1.454137  1.078564  1.082698  1.084270  1.085315
# 138  el150800737213  1.047174  1.048364  1.050240  1.051151  1.052067
# 139  el150800737270  1.065699  1.067577  1.068817  1.069808  1.070383
#
#             5         6         7         8
# 0    1.073530  1.073236  1.074781  1.073434
# 1    1.048233  1.048794  1.049197  1.049617
# 2    1.070008  1.070455  1.070585  1.070803
# 3    1.081451  1.081686  1.081946  1.082068
# 4    1.023703  1.023601  1.023112  1.023580
# ..        ...       ...       ...       ...
# 135  1.082694  1.082749  1.082861  1.082963
# 136  1.074621  1.074464  1.074419  1.074405
# 137  1.086124  1.086118  1.086467  1.086685
# 138  1.052452  1.052797  1.052983  1.053091
# 139  1.070976  1.071374  1.071851  1.072034
#
# [140 rows x 10 columns]

# %%
summary_duration = pd.read_csv("../../Battery_data/summary_charge_duration.csv")
summary_energy = pd.read_csv("../../Battery_data/summary_charge_energy.csv")
summary_throughput = pd.read_csv("../../Battery_data/summary_charge_throughput.csv")
summary_current = pd.read_csv("../../Battery_data/summary_charge_current.csv")
summary_cycle_index = pd.read_csv("../../Battery_data/summary_charge_capacity.csv")
